# %% [markdown]
# ## Treinamento do Modelo CNN
#
# O código abaixo define e treina uma Rede Neural Convolucional (CNN) simples (uma arquitetura baseline) usando o gerador de dados do script_carregar_dados.py.
#
# Ao final do treinamento, o modelo é salvo no formato .keras, que é o arquivo que será carregado e usado para avaliação no script_avaliacao.py.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from script_carregar_dados import create_generators, IMAGE_SIZE, BATCH_SIZE
import os

# --- 1. CONFIGURAÇÕES E CARREGAMENTO DOS DADOS ---
DATASET_PATH = 'chars74k_dataset_final'
MODEL_NAME = 'char_recognition_cnn.keras'
INPUT_SHAPE = (*IMAGE_SIZE, 1) # (64, 64, 1) para imagens em escala de cinza

# 1.1. Geração dos Data Generators
print("Iniciando a criação dos Data Generators...")
train_gen, val_gen, test_gen = create_generators(DATASET_PATH)

# O número de classes é inferido pelo flow_from_directory
NUM_CLASSES = train_gen.num_classes
print(f"Número de classes inferidas: {NUM_CLASSES}")

# --- 2. DEFINIÇÃO DA ARQUITETURA DA CNN (Baseline) ---

model = Sequential([
    # Camada Convolucional 1
    Conv2D(32, (3, 3), activation='relu', input_shape=INPUT_SHAPE),
    MaxPooling2D((2, 2)),
    
    # Camada Convolucional 2
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    
    # Camada Convolucional 3
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    
    # Flatten para alimentar a rede densa
    Flatten(),
    
    # Camada Densa 1
    Dense(512, activation='relu'),
    Dropout(0.5), # Regularização para evitar Overfitting
    
    # Camada de Saída
    Dense(NUM_CLASSES, activation='softmax') # Softmax para classificação multi-classe
])

# --- 3. COMPILAÇÃO DO MODELO ---

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy', # Perda padrão para classificação multi-classe
    metrics=['accuracy']
)

model.summary()

# --- 4. CALLBACKS PARA TREINAMENTO ---

# 4.1. Model Checkpoint: Salva o melhor modelo (baseado na acurácia da validação)
checkpoint = ModelCheckpoint(
    MODEL_NAME, 
    monitor='val_accuracy', 
    save_best_only=True, 
    mode='max', 
    verbose=1
)

# 4.2. Early Stopping: Para o treinamento se a métrica não melhorar após algumas épocas
early_stopping = EarlyStopping(
    monitor='val_loss', 
    patience=5, # Espera por 5 épocas sem melhoria
    restore_best_weights=True
)

callbacks_list = [checkpoint, early_stopping]

# --- 5. TREINAMENTO DO MODELO ---

print("\nIniciando o treinamento...")

# O model.fit_generator (antigo) foi substituído por model.fit com generators
history = model.fit(
    train_gen,
    steps_per_epoch=train_gen.samples // BATCH_SIZE,
    epochs=50, # Defina um número alto e confie no Early Stopping
    validation_data=val_gen,
    validation_steps=val_gen.samples // BATCH_SIZE,
    callbacks=callbacks_list,
    verbose=1
)

print(f"\n✅ Treinamento concluído. O melhor modelo foi salvo como '{MODEL_NAME}'.")
# Out:
# Iniciando a criação dos Data Generators...
# Found 51804 images belonging to 62 classes.
# Found 7367 images belonging to 62 classes.
# Found 7371 images belonging to 62 classes.
# Número de classes inferidas: 62
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)               │ (None, 62, 62, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 31, 31, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 29, 29, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 12, 12, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 512)            │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 62)             │        31,806 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,484,286 (9.48 MB)
#  Trainable params: 2,484,286 (9.48 MB)
#  Non-trainable params: 0 (0.00 B)
# Iniciando o treinamento...
# Epoch 1/50
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.4135 - loss: 2.2487
# Epoch 1: val_accuracy improved from None to 0.80041, saving model to char_recognition_cnn.keras
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 388s 238ms/step - accuracy: 0.5870 - loss: 1.4812 - val_accuracy: 0.8004 - val_loss: 0.6768
# Epoch 2/50
#    1/1618 ━━━━━━━━━━━━━━━━━━━━ 6:34 244ms/step - accuracy: 0.7188 - loss: 0.9911
# Epoch 2: val_accuracy did not improve from 0.80041
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 19s 11ms/step - accuracy: 0.7188 - loss: 0.9911 - val_accuracy: 0.7984 - val_loss: 0.6770
# Epoch 3/50
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.7424 - loss: 0.8259
# Epoch 3: val_accuracy improved from 0.80041 to 0.82255, saving model to char_recognition_cnn.keras
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 350s 216ms/step - accuracy: 0.7510 - loss: 0.8017 - val_accuracy: 0.8226 - val_loss: 0.5812
# Epoch 4/50
#    1/1618 ━━━━━━━━━━━━━━━━━━━━ 9:28 351ms/step - accuracy: 0.8125 - loss: 0.6739
# Epoch 4: val_accuracy improved from 0.82255 to 0.82351, saving model to char_recognition_cnn.keras
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.8125 - loss: 0.6739 - val_accuracy: 0.8235 - val_loss: 0.5734
# Epoch 5/50
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.7746 - loss: 0.7113
# Epoch 5: val_accuracy did not improve from 0.82351
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 350s 216ms/step - accuracy: 0.7754 - loss: 0.6989 - val_accuracy: 0.8192 - val_loss: 0.5444
# Epoch 6/50
#    1/1618 ━━━━━━━━━━━━━━━━━━━━ 9:00 334ms/step - accuracy: 0.7500 - loss: 0.7114
# Epoch 6: val_accuracy did not improve from 0.82351
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - accuracy: 0.7500 - loss: 0.7114 - val_accuracy: 0.8189 - val_loss: 0.5457
# Epoch 7/50
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.7854 - loss: 0.6401
# Epoch 7: val_accuracy improved from 0.82351 to 0.83668, saving model to char_recognition_cnn.keras
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 357s 221ms/step - accuracy: 0.7870 - loss: 0.6376 - val_accuracy: 0.8367 - val_loss: 0.5039
# Epoch 8/50
#    1/1618 ━━━━━━━━━━━━━━━━━━━━ 3:42 138ms/step - accuracy: 0.7500 - loss: 0.5504
# Epoch 8: val_accuracy improved from 0.83668 to 0.83736, saving model to char_recognition_cnn.keras
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.7500 - loss: 0.5504 - val_accuracy: 0.8374 - val_loss: 0.5073
# Epoch 9/50
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.7993 - loss: 0.5981
# Epoch 9: val_accuracy improved from 0.83736 to 0.84117, saving model to char_recognition_cnn.keras
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 347s 215ms/step - accuracy: 0.7970 - loss: 0.5969 - val_accuracy: 0.8412 - val_loss: 0.4807
# Epoch 10/50
#    1/1618 ━━━━━━━━━━━━━━━━━━━━ 6:22 236ms/step - accuracy: 0.7812 - loss: 0.6320
# Epoch 10: val_accuracy improved from 0.84117 to 0.84171, saving model to char_recognition_cnn.keras
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 24s 14ms/step - accuracy: 0.7812 - loss: 0.6320 - val_accuracy: 0.8417 - val_loss: 0.4801
# Epoch 11/50
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.8057 - loss: 0.5702
# Epoch 11: val_accuracy improved from 0.84171 to 0.84891, saving model to char_recognition_cnn.keras
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 346s 207ms/step - accuracy: 0.8055 - loss: 0.5683 - val_accuracy: 0.8489 - val_loss: 0.4482
# Epoch 12/50
#    1/1618 ━━━━━━━━━━━━━━━━━━━━ 3:55 145ms/step - accuracy: 0.8125 - loss: 0.5055
# Epoch 12: val_accuracy did not improve from 0.84891
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.8125 - loss: 0.5055 - val_accuracy: 0.8485 - val_loss: 0.4478
# Epoch 13/50
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.8111 - loss: 0.5431
# Epoch 13: val_accuracy improved from 0.84891 to 0.85000, saving model to char_recognition_cnn.keras
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 355s 220ms/step - accuracy: 0.8116 - loss: 0.5479 - val_accuracy: 0.8500 - val_loss: 0.4466
# Epoch 14/50
#    1/1618 ━━━━━━━━━━━━━━━━━━━━ 4:14 157ms/step - accuracy: 0.8750 - loss: 0.2463
# Epoch 14: val_accuracy did not improve from 0.85000
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.8750 - loss: 0.2463 - val_accuracy: 0.8486 - val_loss: 0.4465
# Epoch 15/50
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.8188 - loss: 0.5116
# Epoch 15: val_accuracy improved from 0.85000 to 0.85258, saving model to char_recognition_cnn.keras
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 372s 221ms/step - accuracy: 0.8162 - loss: 0.5207 - val_accuracy: 0.8526 - val_loss: 0.4363
# Epoch 16/50
#    1/1618 ━━━━━━━━━━━━━━━━━━━━ 7:03 262ms/step - accuracy: 0.8438 - loss: 0.5243
# Epoch 16: val_accuracy did not improve from 0.85258
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.8438 - loss: 0.5243 - val_accuracy: 0.8519 - val_loss: 0.4359
# Epoch 17/50
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.8217 - loss: 0.5093
# Epoch 17: val_accuracy improved from 0.85258 to 0.85965, saving model to char_recognition_cnn.keras
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 355s 219ms/step - accuracy: 0.8233 - loss: 0.5053 - val_accuracy: 0.8596 - val_loss: 0.4116
# Epoch 18/50
#    1/1618 ━━━━━━━━━━━━━━━━━━━━ 4:29 166ms/step - accuracy: 0.7812 - loss: 0.6615
# Epoch 18: val_accuracy improved from 0.85965 to 0.86046, saving model to char_recognition_cnn.keras
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.7812 - loss: 0.6615 - val_accuracy: 0.8605 - val_loss: 0.4118
# Epoch 19/50
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.8236 - loss: 0.4909
# Epoch 19: val_accuracy did not improve from 0.86046
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 356s 220ms/step - accuracy: 0.8243 - loss: 0.4904 - val_accuracy: 0.8556 - val_loss: 0.4072
# Epoch 20/50
#    1/1618 ━━━━━━━━━━━━━━━━━━━━ 4:44 176ms/step - accuracy: 0.9062 - loss: 0.4165
# Epoch 20: val_accuracy did not improve from 0.86046
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.9062 - loss: 0.4165 - val_accuracy: 0.8545 - val_loss: 0.4084
# Epoch 21/50
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.8261 - loss: 0.4826
# Epoch 21: val_accuracy did not improve from 0.86046
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 355s 219ms/step - accuracy: 0.8286 - loss: 0.4767 - val_accuracy: 0.8554 - val_loss: 0.4132
# Epoch 22/50
#    1/1618 ━━━━━━━━━━━━━━━━━━━━ 6:20 236ms/step - accuracy: 0.7500 - loss: 0.8117
# Epoch 22: val_accuracy did not improve from 0.86046
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.7500 - loss: 0.8117 - val_accuracy: 0.8530 - val_loss: 0.4165
# Epoch 23/50
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.8263 - loss: 0.4721
# Epoch 23: val_accuracy improved from 0.86046 to 0.86264, saving model to char_recognition_cnn.keras
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 350s 216ms/step - accuracy: 0.8284 - loss: 0.4728 - val_accuracy: 0.8626 - val_loss: 0.3974
# Epoch 24/50
#    1/1618 ━━━━━━━━━━━━━━━━━━━━ 4:17 159ms/step - accuracy: 0.8750 - loss: 0.3916
# Epoch 24: val_accuracy improved from 0.86264 to 0.86399, saving model to char_recognition_cnn.keras
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.8750 - loss: 0.3916 - val_accuracy: 0.8640 - val_loss: 0.3976
# Epoch 25/50
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.8384 - loss: 0.4508
# Epoch 25: val_accuracy did not improve from 0.86399
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 356s 220ms/step - accuracy: 0.8366 - loss: 0.4540 - val_accuracy: 0.8613 - val_loss: 0.3926
# Epoch 26/50
#    1/1618 ━━━━━━━━━━━━━━━━━━━━ 4:04 151ms/step - accuracy: 0.8438 - loss: 0.4646
# Epoch 26: val_accuracy did not improve from 0.86399
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 20s 12ms/step - accuracy: 0.8438 - loss: 0.4646 - val_accuracy: 0.8621 - val_loss: 0.3898
# Epoch 27/50
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.8392 - loss: 0.4403
# Epoch 27: val_accuracy improved from 0.86399 to 0.86698, saving model to char_recognition_cnn.keras
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 358s 218ms/step - accuracy: 0.8374 - loss: 0.4482 - val_accuracy: 0.8670 - val_loss: 0.3801
# Epoch 28/50
#    1/1618 ━━━━━━━━━━━━━━━━━━━━ 4:07 153ms/step - accuracy: 0.8438 - loss: 0.5522
# Epoch 28: val_accuracy did not improve from 0.86698
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.8438 - loss: 0.5522 - val_accuracy: 0.8663 - val_loss: 0.3798
# Epoch 29/50
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.8389 - loss: 0.4321
# Epoch 29: val_accuracy did not improve from 0.86698
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 350s 216ms/step - accuracy: 0.8394 - loss: 0.4349 - val_accuracy: 0.8562 - val_loss: 0.3925
# Epoch 30/50
#    1/1618 ━━━━━━━━━━━━━━━━━━━━ 4:00 149ms/step - accuracy: 0.8438 - loss: 0.5322
# Epoch 30: val_accuracy did not improve from 0.86698
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.8438 - loss: 0.5322 - val_accuracy: 0.8565 - val_loss: 0.3934
# Epoch 31/50
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.8412 - loss: 0.4204
# Epoch 31: val_accuracy did not improve from 0.86698
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 350s 216ms/step - accuracy: 0.8408 - loss: 0.4296 - val_accuracy: 0.8648 - val_loss: 0.3812
# Epoch 32/50
#    1/1618 ━━━━━━━━━━━━━━━━━━━━ 3:57 147ms/step - accuracy: 0.7812 - loss: 0.4531
# Epoch 32: val_accuracy did not improve from 0.86698
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.7812 - loss: 0.4531 - val_accuracy: 0.8641 - val_loss: 0.3808
# Epoch 33/50
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.8449 - loss: 0.4192
# Epoch 33: val_accuracy did not improve from 0.86698
# 1618/1618 ━━━━━━━━━━━━━━━━━━━━ 380s 235ms/step - accuracy: 0.8427 - loss: 0.4256 - val_accuracy: 0.8599 - val_loss: 0.3970
#
# ✅ Treinamento concluído. O melhor modelo foi salvo como 'char_recognition_cnn.keras'.

# %% [markdown]
# ### Significado de `conv2d_6`
#
# O `_6` após `conv2d` é um **contador de instância** atribuído automaticamente pelo *framework* (Keras ou TensorFlow) para identificar unicamente a camada.
#
# * **`conv2d`**: Indica o tipo de camada (Camada Convolucional 2D).
# * **`_6`**: Significa que esta é a **sexta camada convolucional 2D** que o Keras encontrou e nomeou desde o início do seu modelo ou *notebook*.
#
# Se não especificar um nome manualmente ao criar a camada (ex: `Conv2D(..., name='minha_conv')`), o Keras usa essa convenção de nomenclatura para evitar conflitos.
#
# ---
#
# ### Parâmetros de Saída (`Output Shape`)
#
# A tupla **`(None, 62, 62, 32)`** descreve a forma do **tensor de dados** que esta camada irá produzir e passar para a próxima camada.
#
# | Posição | Valor | Significado |
# | :---: | :---: | :--- |
# | 1º | **`None`** | **Tamanho do Lote (*Batch Size*):** Significa que o modelo pode aceitar qualquer tamanho de lote (número de imagens processadas simultaneamente). Este valor só será definido durante o treinamento (ex: 32). |
# | 2º | **`62`** | **Altura:** A altura do mapa de características de saída (em pixels). |
# | 3º | **`62`** | **Largura:** A largura do mapa de características de saída (em pixels). |
# | 4º | **`32`** | **Profundidade/Canais:** O número de **filtros (kernels)** usados nesta camada $\text{CONV}$. |
#
# **Conclusão:** Esta camada pega uma entrada (provavelmente $64 \times 64$) e, após aplicar a convolução, produz 32 mapas de características, cada um com dimensões de $62 \times 62$ pixels.
#
# ---
#
# ### `Param #` (320)
#
# O **`Param #`** (Número de Parâmetros) representa o número total de **pesos** e **vieses (*biases*)** que o modelo precisa **aprender** ou ajustar durante o treinamento nesta camada específica.
#
# O cálculo para a camada $\text{CONV}$ segue a fórmula:
#
# $$\text{Params} = ((\text{Tamanho do Filtro} \times \text{Tamanho do Filtro} \times \text{Canais de Entrada}) + 1) \times \text{Canais de Saída}$$
#
# O cálculo para $\text{320}$ sugere:
#
# 1.  **Canais de Saída:** $32$ (dado no `Output Shape`).
# 2.  **Canais de Entrada:** $1$ (Se a camada anterior for a imagem de entrada em escala de cinza, $64 \times 64 \times 1$).
# 3.  **Tamanho do Filtro:** $3 \times 3$ (Valor padrão se não especificado).
#
# **Cálculo:**
# $$\text{Params} = ((3 \times 3 \times 1) + 1) \times 32$$
# $$\text{Params} = (9 + 1) \times 32$$
# $$\text{Params} = 10 \times 32 = 320$$
#
# **Conclusão:** O valor **320** representa o número de **pesos ajustáveis** nesta camada, que são os pesos dos 32 filtros $3 \times 3$ e seus respectivos vieses.
